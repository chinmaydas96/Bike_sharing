# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv('OPENDATA_BOOKING_CALL_A_BIKE.csv',sep=";")

# %%
# df.head()
# Out:
#    BOOKING_HAL_ID  CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# 0        21366843            51000          143517
# 1        21367069            51000          119830
# 2        21367072            51000          143501
# 3        21367118            51000          117519
# 4        21367155            51000          108641
#
#                             CUSTOMER_HAL_ID         DATE_BOOKING  \
# 0  A821059B555C7764A2FF801180874A2FCB326222  2014-01-01 00:34:54
# 1  1EBC930DB407ACEAE2FDE23A6CA40492EA3DFBB2  2014-01-01 01:39:55
# 2  7AD2C1B70137479062A6DD73815835986677BB2D  2014-01-01 01:40:20
# 3  A1062EF019B4E3E71C551572F1B284D55440E3C4  2014-01-01 01:56:00
# 4  4F4F752203EA6FC872D576E9289C4E1B362E16F6  2014-01-01 02:05:55
#
#              DATE_FROM           DATE_UNTIL COMPUTE_EXTRA_BOOKING_FEE  \
# 0  2014-01-01 00:34:54  2014-01-01 00:50:14                      Nein
# 1  2014-01-01 01:39:55  2014-01-01 01:57:27                      Nein
# ...

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16228298 entries, 0 to 16228297
# Data columns (total 17 columns):
# BOOKING_HAL_ID               int64
# CATEGORY_HAL_ID              int64
# VEHICLE_HAL_ID               int64
# CUSTOMER_HAL_ID              object
# DATE_BOOKING                 object
# DATE_FROM                    object
# DATE_UNTIL                   object
# COMPUTE_EXTRA_BOOKING_FEE    object
# TRAVERSE_USE                 object
# DISTANCE                     float64
# START_RENTAL_ZONE            object
# START_RENTAL_ZONE_HAL_ID     float64
# END_RENTAL_ZONE              object
# END_RENTAL_ZONE_HAL_ID       float64
# RENTAL_ZONE_HAL_SRC          object
# CITY_RENTAL_ZONE             object
# TECHNICAL_INCOME_CHANNEL     object
# dtypes: float64(3), int64(3), object(11)
# memory usage: 2.1+ GB

# %%
# df['date'] = pd.to_datetime(df['DATE_BOOKING'])

# %%
# df['date'].head()
# Out:
# 0   2014-01-01 00:34:54
# 1   2014-01-01 01:39:55
# 2   2014-01-01 01:40:20
# 3   2014-01-01 01:56:00
# 4   2014-01-01 02:05:55
# Name: date, dtype: datetime64[ns]

# %%
# df.index = df['date']

# %%
# del df['date']

# %%
# df.head()
# Out:
#                      BOOKING_HAL_ID  CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# date
# 2014-01-01 00:34:54        21366843            51000          143517
# 2014-01-01 01:39:55        21367069            51000          119830
# 2014-01-01 01:40:20        21367072            51000          143501
# 2014-01-01 01:56:00        21367118            51000          117519
# 2014-01-01 02:05:55        21367155            51000          108641
#
#                                               CUSTOMER_HAL_ID  \
# date
# 2014-01-01 00:34:54  A821059B555C7764A2FF801180874A2FCB326222
# 2014-01-01 01:39:55  1EBC930DB407ACEAE2FDE23A6CA40492EA3DFBB2
# 2014-01-01 01:40:20  7AD2C1B70137479062A6DD73815835986677BB2D
# 2014-01-01 01:56:00  A1062EF019B4E3E71C551572F1B284D55440E3C4
# 2014-01-01 02:05:55  4F4F752203EA6FC872D576E9289C4E1B362E16F6
#
#                             DATE_BOOKING            DATE_FROM  \
# date
# 2014-01-01 00:34:54  2014-01-01 00:34:54  2014-01-01 00:34:54
# ...

# %%
# creating new dataframe

# df['2016-01-01':'2016-12-31'].to_csv('2016_Call_a_bike.csv', sep=',', encoding='utf-8')
# df['2017-01-01':].to_csv('2017_Call_a_bike.csv', sep=',', encoding='utf-8')

# %%
# df_2016.head()
# Out:
#                      BOOKING_HAL_ID  CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# date
# 2016-01-01 00:44:49        34948004            51000          108647
# 2016-01-01 00:31:46        34947949            51000          108371
# 2016-01-01 00:38:37        34947974            51000          119829
# 2016-01-01 01:11:00        34948134            51000          116810
# 2016-01-01 01:06:17        34948107            51000          120345
#
#                                               CUSTOMER_HAL_ID  \
# date
# 2016-01-01 00:44:49  0BFC9CA3CA75AEAE16A6BF86913AF5D8613B20BD
# 2016-01-01 00:31:46  48A88184B22E7171E8A03E34FF32E761DD83CA92
# 2016-01-01 00:38:37  F84BCAB7154C63B9E4A7E7EA13BB4FA493539A12
# 2016-01-01 01:11:00  7D8127DA8F382BF2C3A8FD31202D46A150A513AE
# 2016-01-01 01:06:17  AEE37262F04CB04681868F6E8CEE2D7F9CDA6997
#
#                             DATE_BOOKING            DATE_FROM  \
# date
# 2016-01-01 00:44:49  2016-01-01 00:44:49  2016-01-01 00:44:49
# ...

# %%
df_2016 = pd.read_csv('2016_Call_a_bike.csv')

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5702575 entries, 0 to 5702574
# Data columns (total 18 columns):
# date                         object
# BOOKING_HAL_ID               int64
# CATEGORY_HAL_ID              int64
# VEHICLE_HAL_ID               int64
# CUSTOMER_HAL_ID              object
# DATE_BOOKING                 object
# DATE_FROM                    object
# DATE_UNTIL                   object
# COMPUTE_EXTRA_BOOKING_FEE    object
# TRAVERSE_USE                 object
# DISTANCE                     float64
# START_RENTAL_ZONE            object
# START_RENTAL_ZONE_HAL_ID     float64
# END_RENTAL_ZONE              object
# END_RENTAL_ZONE_HAL_ID       float64
# RENTAL_ZONE_HAL_SRC          object
# CITY_RENTAL_ZONE             object
# TECHNICAL_INCOME_CHANNEL     object
# dtypes: float64(3), int64(3), object(12)
# memory usage: 783.1+ MB

# %%
df_2016[df_2016.TECHNICAL_INCOME_CHANNEL == 'Android SRH'].shape
# Out:
# (641988, 18)

# %%
df_2016.CITY_RENTAL_ZONE.unique()
# Out:
# array(['Hamburg', 'Kassel', 'Darmstadt', 'Frankfurt am Main', 'Marburg',
#        'Berlin', 'Stuttgart', 'Köln', 'München', 'Wiesbaden',
#        'Rüsselsheim', 'Weimar', 'Mannheim', 'Karlsruhe', 'Bonn', 'Halle',
#        'Lübeck', 'Baden-Baden', 'Bamberg', 'Göttingen', 'Flugh. Frankfurt',
#        'Oberhausen', 'Freiburg', 'Kiel', 'Würzburg', 'Erlangen',
#        'Düsseldorf', 'Fulda', 'Troisdorf', 'Oldenburg (Oldb)',
#        'Heidelberg', 'Warnemünde', 'Gütersloh', 'Bremen', 'Mainz',
#        'Saarbrücken', 'Hannover', 'Aschaffenburg', 'Rostock', 'Hanau',
#        'Ingolstadt', 'Braunschweig', 'Magdeburg', 'Kaiserslautern',
#        'Bielefeld', 'Hennef'], dtype=object)

# %%
df_2016.CITY_RENTAL_ZONE.unique().shape
# Out:
# (46,)

# %%
df_2016[df_2016.RENTAL_ZONE_HAL_SRC != 'Standort'].shape
# Out:
# (103756, 18)

# %%
df_2016.shape
# Out:
# (5702575, 18)

# %%
df_2016.dropna(how='any').shape
# Out:
# (4276986, 18)

# %%
5702575 - 4276986
# Out:
# 1425589

# %%
df_2016.CUSTOMER_HAL_ID.unique().shape
# Out:
# (267115,)

# %%
df_2016.TRAVERSE_USE.unique()
# Out:
# array(['Nein'], dtype=object)

# %%
df_2016.drop(['COMPUTE_EXTRA_BOOKING_FEE', 'TRAVERSE_USE'], axis=1, inplace=True)

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5702575 entries, 0 to 5702574
# Data columns (total 15 columns):
# date                        object
# BOOKING_HAL_ID              int64
# CATEGORY_HAL_ID             int64
# VEHICLE_HAL_ID              int64
# CUSTOMER_HAL_ID             object
# DATE_BOOKING                object
# DATE_FROM                   object
# DATE_UNTIL                  object
# START_RENTAL_ZONE           object
# START_RENTAL_ZONE_HAL_ID    float64
# END_RENTAL_ZONE             object
# END_RENTAL_ZONE_HAL_ID      float64
# RENTAL_ZONE_HAL_SRC         object
# CITY_RENTAL_ZONE            object
# TECHNICAL_INCOME_CHANNEL    object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 652.6+ MB

# %%
df_2016.BOOKING_HAL_ID.unique().shape
# Out:
# (5702575,)

# %%
df_2016.CATEGORY_HAL_ID.unique()
# Out:
# array([51000, 53000, 50000, 50001])

# %%
df_2016.VEHICLE_HAL_ID.unique().shape
# Out:
# (10527,)

# %%
df_2016.drop(['DISTANCE'], axis=1, inplace=True)

# %%
df_2016.head(10)
# Out:
#                   date  BOOKING_HAL_ID  CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# 0  2016-01-01 00:44:49        34948004            51000          108647
# 1  2016-01-01 00:31:46        34947949            51000          108371
# 2  2016-01-01 00:38:37        34947974            51000          119829
# 3  2016-01-01 01:11:00        34948134            51000          116810
# 4  2016-01-01 01:06:17        34948107            51000          120345
# 5  2016-01-01 01:24:50        34948223            53000          117442
# 6  2016-01-01 00:08:54        34947894            50000          107059
# 7  2016-01-01 00:27:53        34947937            50000          107059
# 8  2016-01-01 00:30:33        34947942            51000          119362
# 9  2016-01-01 01:06:19        34948109            51000          109225
#
#                             CUSTOMER_HAL_ID         DATE_BOOKING  \
# 0  0BFC9CA3CA75AEAE16A6BF86913AF5D8613B20BD  2016-01-01 00:44:49
# ...

# %%
df_2016.END_RENTAL_ZONE.unique().shape
# Out:
# (824,)

# %%
df_2016.END_RENTAL_ZONE_HAL_ID.unique().shape
# Out:
# (14190,)

# %%
df_2016.START_RENTAL_ZONE.unique().shape
# Out:
# (822,)

# %%
df_2016.START_RENTAL_ZONE_HAL_ID.unique().shape
# Out:
# (13951,)

# %%
df_2016.index = df_2016['date']
del df_2016['date']
del df_2016['BOOKING_HAL_ID']

# %%
df_2016.head()
# Out:
#                      CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# date
# 2016-01-01 00:44:49            51000          108647
# 2016-01-01 00:31:46            51000          108371
# 2016-01-01 00:38:37            51000          119829
# 2016-01-01 01:11:00            51000          116810
# 2016-01-01 01:06:17            51000          120345
#
#                                               CUSTOMER_HAL_ID  \
# date
# 2016-01-01 00:44:49  0BFC9CA3CA75AEAE16A6BF86913AF5D8613B20BD
# 2016-01-01 00:31:46  48A88184B22E7171E8A03E34FF32E761DD83CA92
# 2016-01-01 00:38:37  F84BCAB7154C63B9E4A7E7EA13BB4FA493539A12
# 2016-01-01 01:11:00  7D8127DA8F382BF2C3A8FD31202D46A150A513AE
# 2016-01-01 01:06:17  AEE37262F04CB04681868F6E8CEE2D7F9CDA6997
#
#                             DATE_BOOKING            DATE_FROM  \
# date
# 2016-01-01 00:44:49  2016-01-01 00:44:49  2016-01-01 00:44:49
# 2016-01-01 00:31:46  2016-01-01 00:31:46  2016-01-01 00:31:46
# ...

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5702575 entries, 2016-01-01 00:44:49 to 2016-12-31 23:54:05
# Data columns (total 12 columns):
# CATEGORY_HAL_ID             int64
# VEHICLE_HAL_ID              int64
# CUSTOMER_HAL_ID             object
# DATE_FROM                   object
# DATE_UNTIL                  object
# START_RENTAL_ZONE           object
# START_RENTAL_ZONE_HAL_ID    float64
# END_RENTAL_ZONE             object
# END_RENTAL_ZONE_HAL_ID      float64
# RENTAL_ZONE_HAL_SRC         object
# CITY_RENTAL_ZONE            object
# TECHNICAL_INCOME_CHANNEL    object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 565.6+ MB

# %%
del df_2016['DATE_BOOKING']

# %%
df_2016.index = pd.to_datetime(df_2016['DATE_FROM'])
df_2016.index.names = ['Date']

# %%
df_2016.head()
# Out:
#                      CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# Date
# 2016-01-01 00:44:49            51000          108647
# 2016-01-01 00:31:46            51000          108371
# 2016-01-01 00:38:37            51000          119829
# 2016-01-01 01:11:00            51000          116810
# 2016-01-01 01:06:17            51000          120345
#
#                                               CUSTOMER_HAL_ID  \
# Date
# 2016-01-01 00:44:49  0BFC9CA3CA75AEAE16A6BF86913AF5D8613B20BD
# 2016-01-01 00:31:46  48A88184B22E7171E8A03E34FF32E761DD83CA92
# 2016-01-01 00:38:37  F84BCAB7154C63B9E4A7E7EA13BB4FA493539A12
# 2016-01-01 01:11:00  7D8127DA8F382BF2C3A8FD31202D46A150A513AE
# 2016-01-01 01:06:17  AEE37262F04CB04681868F6E8CEE2D7F9CDA6997
#
#                                DATE_FROM           DATE_UNTIL  \
# Date
# 2016-01-01 00:44:49  2016-01-01 00:44:49  2016-01-01 01:13:37
# 2016-01-01 00:31:46  2016-01-01 00:31:46  2016-01-01 00:58:49
# ...

# %%
# date time fix
